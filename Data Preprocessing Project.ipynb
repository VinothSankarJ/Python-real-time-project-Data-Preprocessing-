# %%
import pandas as pd

# %%
dataset=pd.read_csv("Inputdata.csv")

# %%
dataset
# Out:
#                                         Campaign name        Day  \
# 0                         ForeignSales-AsiaAntartrica  3/31/2024
# 1                                         Feedbackrs9  3/31/2024
# 2                         ForeignSales-AsiaAntartrica  3/29/2024
# 3                                         Feedbackrs9  3/28/2024
# 4                         ForeignSales-AsiaAntartrica  3/27/2024
# 5                         ForeignSales-AsiaAntartrica  3/26/2024
# 6                                         Feedbackrs9  3/26/2024
# 7                         ForeignSales-AsiaAntartrica  3/25/2024
# 8                         ForeignSales-AsiaAntartrica  3/24/2024
# 9                                         Feedbackrs9  3/24/2024
# 10                                        Feedbackrs9  3/23/2024
# 11                        ForeignSales-AsiaAntartrica  3/23/2024
# 12                        ForeignSales-AsiaAntartrica  3/22/2024
# ...

# %%
dataset.isnull().sum()
# Out:
# Campaign name                          0
# Day                                    0
# Delivery status                        0
# Delivery level                         0
# Amount spent (INR)                     0
# Impressions                            0
# CPM (cost per 1,000 impressions)      20
# Reach                                  0
# Frequency                              0
# CTR (link click-through rate)         20
# Video plays                           20
# Video plays at 100%                   20
# CTR (all)                             20
# Link clicks                           20
# Landing page views                    20
# Result Type                           18
# Results                               17
# Purchase ROAS (return on ad spend)    35
# Attribution setting                    0
# Cost per result                       18
# Reporting starts                       0
# Reporting ends                         0
# dtype: int64

# %%
dataset["CPM (cost per 1,000 impressions)"].fillna(0,inplace=True)

# %%
dataset["CTR (link click-through rate)"].fillna(0,inplace=True)

# %%
dataset["Video plays"].fillna(0,inplace=True)

# %%
dataset["Video plays at 100%"].fillna(0,inplace=True)

# %%
dataset["CTR (all)"].fillna(0,inplace=True)

# %%
dataset["Link clicks"].fillna(0,inplace=True)

# %%
dataset["Landing page views"].fillna(0,inplace=True)

# %%
dataset["Result Type"].fillna(0,inplace=True)

# %%
dataset["Results"].fillna(0,inplace=True)
dataset["Purchase ROAS (return on ad spend)"].fillna(0,inplace=True)
dataset["Cost per result"].fillna(0,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Campaign name                         0
# Day                                   0
# Delivery status                       0
# Delivery level                        0
# Amount spent (INR)                    0
# Impressions                           0
# CPM (cost per 1,000 impressions)      0
# Reach                                 0
# Frequency                             0
# CTR (link click-through rate)         0
# Video plays                           0
# Video plays at 100%                   0
# CTR (all)                             0
# Link clicks                           0
# Landing page views                    0
# Result Type                           0
# Results                               0
# Purchase ROAS (return on ad spend)    0
# Attribution setting                   0
# Cost per result                       0
# Reporting starts                      0
# Reporting ends                        0
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#                                         Campaign name        Day  \
# 0                         ForeignSales-AsiaAntartrica  3/31/2024
# 1                                         Feedbackrs9  3/31/2024
# 2                         ForeignSales-AsiaAntartrica  3/29/2024
# 3                                         Feedbackrs9  3/28/2024
# 4                         ForeignSales-AsiaAntartrica  3/27/2024
# 5                         ForeignSales-AsiaAntartrica  3/26/2024
# 6                                         Feedbackrs9  3/26/2024
# 7                         ForeignSales-AsiaAntartrica  3/25/2024
# 8                         ForeignSales-AsiaAntartrica  3/24/2024
# 9                                         Feedbackrs9  3/24/2024
# 10                                        Feedbackrs9  3/23/2024
# 11                        ForeignSales-AsiaAntartrica  3/23/2024
# 12                        ForeignSales-AsiaAntartrica  3/22/2024
# ...

# %%
dataset["CPM (cost per 1,000 impressions)"].fillna(dataset["CPM (cost per 1,000 impressions)"].mean(),inplace=True)
dataset["CTR (link click-through rate)"].fillna(dataset["CTR (link click-through rate)"].mean(),inplace=True)
dataset["Video plays"].fillna(dataset["Video plays"].mean(),inplace=True)
dataset["Video plays at 100%"].fillna(dataset["Video plays at 100%"].mean(),inplace=True)
dataset["CTR (all)"].fillna(dataset["CTR (all)"].mean(),inplace=True)
dataset["Link clicks"].fillna(dataset["Link clicks"].mean(),inplace=True)
dataset["Landing page views"].fillna(dataset["Landing page views"].mean(),inplace=True)
dataset["Results"].fillna(dataset["Results"].mean(),inplace=True)
dataset["Purchase ROAS (return on ad spend)"].fillna(dataset["Purchase ROAS (return on ad spend)"].mean(),inplace=True)
dataset["Cost per result"].fillna(dataset["Cost per result"].mean(),inplace=True)

# %%
dataset
# Out:
#                                         Campaign name        Day  \
# 0                         ForeignSales-AsiaAntartrica  3/31/2024
# 1                                         Feedbackrs9  3/31/2024
# 2                         ForeignSales-AsiaAntartrica  3/29/2024
# 3                                         Feedbackrs9  3/28/2024
# 4                         ForeignSales-AsiaAntartrica  3/27/2024
# 5                         ForeignSales-AsiaAntartrica  3/26/2024
# 6                                         Feedbackrs9  3/26/2024
# 7                         ForeignSales-AsiaAntartrica  3/25/2024
# 8                         ForeignSales-AsiaAntartrica  3/24/2024
# 9                                         Feedbackrs9  3/24/2024
# 10                                        Feedbackrs9  3/23/2024
# 11                        ForeignSales-AsiaAntartrica  3/23/2024
# 12                        ForeignSales-AsiaAntartrica  3/22/2024
# ...

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan,qaul=quanQual(dataset)

# %%
dataset[quan]
# Out:
#     Amount spent (INR)  Impressions  CPM (cost per 1,000 impressions)  Reach  \
# 0              1033.89        21966                          47.06774  20810
# 1               497.70         5774                          86.19674   5590
# 2                 0.00            0                           0.00000      0
# 3                 0.00            0                           0.00000      0
# 4                 0.00            0                           0.00000      0
# 5                 0.00            0                           0.00000      0
# 6                 0.00            0                           0.00000      0
# 7                 0.00            0                           0.00000      0
# 8               815.22        16770                          48.61181  15373
# 9              1573.42        20822                          75.56527  19635
# 10             1941.17        25353                          76.56569  23188
# ...

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(dataset[quan])
df=imp.transform(dataset[quan])
df = pd.DataFrame(df,columns = quan)

# %%
imp
# Out:
# SimpleImputer()

# %%
dataset
# Out:
#                                         Campaign name        Day  \
# 0                         ForeignSales-AsiaAntartrica  3/31/2024
# 1                                         Feedbackrs9  3/31/2024
# 2                         ForeignSales-AsiaAntartrica  3/29/2024
# 3                                         Feedbackrs9  3/28/2024
# 4                         ForeignSales-AsiaAntartrica  3/27/2024
# 5                         ForeignSales-AsiaAntartrica  3/26/2024
# 6                                         Feedbackrs9  3/26/2024
# 7                         ForeignSales-AsiaAntartrica  3/25/2024
# 8                         ForeignSales-AsiaAntartrica  3/24/2024
# 9                                         Feedbackrs9  3/24/2024
# 10                                        Feedbackrs9  3/23/2024
# 11                        ForeignSales-AsiaAntartrica  3/23/2024
# 12                        ForeignSales-AsiaAntartrica  3/22/2024
# ...

# %%
df
# Out:
#     Amount spent (INR)  Impressions  CPM (cost per 1,000 impressions)  \
# 0              1033.89      21966.0                          47.06774
# 1               497.70       5774.0                          86.19674
# 2                 0.00          0.0                           0.00000
# 3                 0.00          0.0                           0.00000
# 4                 0.00          0.0                           0.00000
# 5                 0.00          0.0                           0.00000
# 6                 0.00          0.0                           0.00000
# 7                 0.00          0.0                           0.00000
# 8               815.22      16770.0                          48.61181
# 9              1573.42      20822.0                          75.56527
# 10             1941.17      25353.0                          76.56569
# 11              964.12      18951.0                          50.87436
# ...

# %%
cate=dataset[qaul]

# %%
df
# Out:
#     Amount spent (INR)  Impressions  CPM (cost per 1,000 impressions)  \
# 0              1033.89      21966.0                          47.06774
# 1               497.70       5774.0                          86.19674
# 2                 0.00          0.0                           0.00000
# 3                 0.00          0.0                           0.00000
# 4                 0.00          0.0                           0.00000
# 5                 0.00          0.0                           0.00000
# 6                 0.00          0.0                           0.00000
# 7                 0.00          0.0                           0.00000
# 8               815.22      16770.0                          48.61181
# 9              1573.42      20822.0                          75.56527
# 10             1941.17      25353.0                          76.56569
# 11              964.12      18951.0                          50.87436
# ...

# %%
dataset['No. of Leads'] = dataset['Results']  
dataset['Cost Per Lead'] = dataset['Amount spent (INR)'] / dataset['No. of Leads']
dataset['Member passed'] = (dataset['Landing page views'] / dataset['Link clicks']) * 100
dataset['LP Conversion'] = (dataset['No. of Leads'] / dataset['Landing page views']) * 100

# %%
output_df = dataset[['Day', 'Campaign name', 'Amount spent (INR)', 'No. of Leads', 'Cost Per Lead',
                     'CTR (link click-through rate)', 'Link clicks', 'Landing page views',
                     'Member passed', 'LP Conversion']]

# %%
dataset
# Out:
#                                         Campaign name        Day  \
# 0                         ForeignSales-AsiaAntartrica  3/31/2024
# 1                                         Feedbackrs9  3/31/2024
# 2                         ForeignSales-AsiaAntartrica  3/29/2024
# 3                                         Feedbackrs9  3/28/2024
# 4                         ForeignSales-AsiaAntartrica  3/27/2024
# 5                         ForeignSales-AsiaAntartrica  3/26/2024
# 6                                         Feedbackrs9  3/26/2024
# 7                         ForeignSales-AsiaAntartrica  3/25/2024
# 8                         ForeignSales-AsiaAntartrica  3/24/2024
# 9                                         Feedbackrs9  3/24/2024
# 10                                        Feedbackrs9  3/23/2024
# 11                        ForeignSales-AsiaAntartrica  3/23/2024
# 12                        ForeignSales-AsiaAntartrica  3/22/2024
# ...

# %%
output_df.to_csv('processed_data.csv', index=False)
